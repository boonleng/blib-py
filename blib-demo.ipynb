# %%
# %matplotlib inline

# %%
import os
import sys
import matplotlib

sys.path.insert(0, os.path.expanduser('~') + 'Developer/blib-py')

import blib

# %%
blib.showSwatch(blib.swatch)

# %%
blib.swatch[2]
# Out:
# ('lightcoral', RGB(red=240, green=128, blue=128))
